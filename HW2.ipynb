# %% [markdown]
# <a href="https://colab.research.google.com/github/DAvidtai1215/TKU-AI-412637281/blob/main/HW2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install easyocr

import easyocr
import cv2
import matplotlib.pyplot as plt

from google.colab import files

# 上傳機車車牌影像檔案
uploaded = files.upload()

# 初始化 OCR 引擎
ocr = easyocr.Reader(['en'])

# 逐一處理上傳的影像檔案
for filepath in uploaded.keys():
    img = cv2.imread(filepath)

    # 進行文字辨識
    result = ocr.readtext(img)

    # 顯示機車車牌影像
    plt.imshow(img)
    plt.axis('off')
    plt.show()

    # 顯示辨識結果
    for bbox, text, score in result:
        print(f'Text: {text} (Confidence: {score:.2f})')
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 13.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 25.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 20.8 MB/s eta 0:00:00
# ...
#      <input type="file" id="files-331150f4-d17f-456d-a74d-d5b9dc259ef3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-331150f4-d17f-456d-a74d-d5b9dc259ef3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# ...
